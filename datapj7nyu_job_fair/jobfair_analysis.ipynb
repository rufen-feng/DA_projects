# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_info_columns', 500)
pd.set_option('display.max_info_rows', 2000)
pd.set_option('display.expand_frame_repr', True)
pd.set_option('display.width', 2000)
pd.set_option('display.max_rows', 500)

# %%
data = pd.read_excel('/Users/rufen/Downloads/nyu_job_fair/Fall 2023 NYU job.xlsx')
data.head()
# Out:
#                 Employer      Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                           Website        Job Types                                                                                  School Years Accepts CPT/OPT Able to Sponsor
# ...

# %%
data.shape
# Out:
# (208, 8)

# %%
data.columns
# Out:
# Index(['Employer', 'Employer Industry', 'Description', 'Website', 'Job Types', 'School Years', 'Accepts CPT/OPT', 'Able to Sponsor'], dtype='object')

# %%
data.rename(columns={'Accepts CPT/OPT':'opt/cpt', 'Able to Sponsor': 'sponsor'}, inplace=True)
data.head()
# Out:
#                 Employer      Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                           Website        Job Types                                                                                  School Years opt/cpt sponsor
# ...

# %%
sponsor_filter = data[(data['opt/cpt']=='Yes') | (data['sponsor']=='Yes')]
sponsor_filter

print(sponsor_filter.shape)
# Out:
# (88, 8)

# %%
list(sponsor_filter['Employer'])
# Out:
# ['Advance Care Alliance',
#  'AllianceBernstein',
#  'AlphaSights',
#  'Asphalt Green',
#  'Axiom Learning',
#  'Barclays',
#  'BearingPoint',
#  'BGB Group',
#  'Black Rocket Productions',
#  'Boehringer Ingelheim Corporation',
#  'BrainStation',
#  'Brookfield Properties',
#  'C3 AI',
#  'CAC Specialty',
#  'Cboe Global Markets',
#  'CenterLight Health System',
#  'CheersYou International Consulting Inc',
#  'Christian Dior Inc.',
#  'Clipboard Health',
#  'Colliers Engineering & Design',
#  'Delta Partners',
#  'DV Trading, LLC',
#  'Edelman',
#  'EHOMIE NEW YORK INC.',
#  'Eli Lilly and Company',
#  'Equinor',
#  'EssilorLuxottica',
#  'Explore Schools',
#  'EY LLP',
#  'Firmenich, Inc.',
#  'Flow Traders',
#  'Garg Consulting Services, Inc. (Garg)',
#  'Gateway Counseling Center, Inc.',
#  'Genius Gems, LLC',
#  'Glencore Ltd',
#  'Global Kids',
#  'Group PMX',
#  'Gupta Media',
#  'Hazen and Sawyer',
#  'Health Advances, LLC',
#  'HelloFresh',
#  'Hill International, Inc.',
# ...

# %%
job_filter = data[data['Job Types'].str.contains('job', case=False, na=False)]
job_filter.shape
# Out:
# (162, 8)

# %%
list(job_filter['Employer'])
# Out:
# ['3forge',
#  'Achievement First',
#  'Activate Inc.',
#  'Advance Care Alliance',
#  'AECOM',
#  'AllianceBernstein',
#  'Allied Beverage Group, LLC',
#  'AlphaSights',
#  'Alvarez & Marsal, LLC',
#  'Ameriprise Financial',
#  'Asphalt Green',
#  'Association of Public Health Laboratories',
#  'Astor Services For Children and Families',
#  'Atrium Staffing',
#  'Axiom Learning',
#  'Bank of China',
#  'Barclays',
#  'Beacon Hill Staffing Group',
#  'BearingPoint',
#  'BGB Group',
#  'Birch Family Services',
#  'Black Rocket Productions',
#  "Bloomingdale's",
#  'BNP Paribas',
#  'Boehringer Ingelheim Corporation',
#  'BrainStation',
#  'Brookfield Properties',
#  'C3 AI',
#  'Cadmus',
#  'Capco',
#  'Capital Preparatory Schools',
#  'Cboe Global Markets',
#  'CBRE Investment Management',
#  'CenterLight Health System',
#  'CheersYou International Consulting Inc',
#  'Christian Dior Inc.',
#  'Clipboard Health',
#  'Colliers Engineering & Design',
#  'Compass',
# ...

# %%
set1 = set(job_filter['Employer'])
set2 = set(sponsor_filter['Employer'])

intersection = set1.intersection(set2)

intersection_list = list(intersection)

print(intersection_list)
print(len(intersection_list))
# Out:
# ['TotalEnergies', 'EY LLP', 'Gupta Media', 'Barclays', 'Garg Consulting Services, Inc. (Garg)', 'Christian Dior Inc.', 'New York City Economic Development Corporation', 'TruStage', 'Thinktown Education Inc.', 'Flow Traders', 'Vcheck Global', 'Colliers Engineering & Design', 'KBRA', 'Health Advances, LLC', 'Tetra Tech, Inc.', 'Verition Fund Management', 'Kimber Health', 'PVE, LLC', 'Gateway Counseling Center, Inc.', 'CheersYou International Consulting Inc', 'Asphalt Green', 'Brookfield Properties', 'Genius Gems, LLC', 'Clipboard Health', 'OHLA USA', 'Teneo', 'AllianceBernstein', 'Third Bridge', 'Sia Partners US, Inc.', 'Glencore Ltd', 'University Settlement Society of New York', 'Via', 'VAANDU', 'Axiom Learning', 'InterSystems', 'NY Kids Club & NY Preschool', 'New York City Housing Development Corp.', 'BrainStation', 'Black Rocket Productions', 'TikTok Inc.', 'C3 AI', 'HelloFresh', 'Konrad Group', 'BearingPoint', 'Sky Harbour', 'ICONIQ Capital', 'PwC', 'BGB Group', 'The Rockefeller Un
# ...

# %%
final_data = pd.DataFrame(intersection_list)
final_data
# Out:
#                                                                                0
# 0                                                                  TotalEnergies
# 1                                                                         EY LLP
# 2                                                                    Gupta Media
# 3                                                                       Barclays
# 4                                          Garg Consulting Services, Inc. (Garg)
# 5                                                            Christian Dior Inc.
# 6                                 New York City Economic Development Corporation
# 7                                                                       TruStage
# 8                                                       Thinktown Education Inc.
# 9                                                                   Flow Traders
# 10                                                                 Vcheck Global
# ...

# %%
data2 = data[data['Employer'].isin (intersection_list)]
data2
# Out:
#                                                                          Employer                    Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                                           Website                               Job Types                                                                                                                                                                                                                         School Years opt/cpt sponsor
# ...

# %%
# delete non-profit and other unsatisfied employers 
data2.shape
# Out:
# (68, 8)

# %%
data3 = data2[data2['Employer Industry'] != 'Non-Profit - Other']
data3
# Out:
#                                                                          Employer                    Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                                           Website                               Job Types                                                                                                                                                                                                                         School Years opt/cpt sponsor
# ...

# %%
# find company that hire my interest and my major(on handshake)
financial = data3[data3['Employer Industry'] == 'Financial Services']
print(financial.shape)
financial
# Out:
# (3, 8)
#         Employer   Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                        Website        Job Types                                                 School Years opt/cpt sponsor
# ...

# %%
ad_mkt = data3[data3['Employer Industry']=='Advertising, PR & Marketing']
print(ad_mkt.shape)
ad_mkt
# Out:
# (4, 8)
#         Employer            Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                     Website        Job Types                                                 School Years opt/cpt sponsor
# ...

# %%
# pwc, vanguard, tiktok, BCG group,
# , epic-epic, EY-llc, verition fundation managemnt

# barclays the first

# %%
# all financial service 
all_financial=data[data['Employer Industry'] == 'Financial Services']
print(all_financial.shape)
all_financial
# Out:
# (11, 8)
#                                Employer   Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                                              Website                         Job Types                                                                                                                                                                   School Years opt/cpt sponsor
# ...

# %%
data['Employer Industry'].value_counts()
# Out:
# Management Consulting                  14
# Non-Profit - Other                     14
# Internet & Software                    12
# Investment / Portfolio Management      12
# Government - Local, State & Federal    11
# Financial Services                     11
# K-12 Education                         10
# Legal & Law Enforcement                 9
# Construction                            9
# Insurance                               8
# Advertising, PR & Marketing             8
# Real Estate                             8
# Other Education                         7
# Healthcare                              7
# Civil Engineering                       6
# Investment Banking                      5
# Defense                                 4
# Scientific and Technical Consulting     4
# CPG - Consumer Packaged Goods           4
# Accounting                              4
# Commercial Banking & Credit             4
# Hotels & Accommodation                  3
# ...

# %%
banking = data[data['Employer Industry']=='Commercial Banking & Credit']
banking
# Out:
#                                 Employer            Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                                         Website        Job Types                                                                                                               School Years opt/cpt sponsor
# ...

# %%
investment = data[data['Employer Industry']=='Investment Banking']
print(investment.shape)
investment
# Out:
# (5, 8)
#                             Employer   Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                                                                Website        Job Types                         School Years opt/cpt sponsor
# ...

# %%
data[data['Employer Industry']=='Scientific and Technical Consulting']
# Out:
#                                       Employer                    Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                                                  Website                                           Job Types                                                                                                                                                                                                                         School Years opt/cpt sponsor
# ...

# %%
all_financial['Employer']
# Out:
# 18                               Barclays
# 66                           Flow Traders
# 71        Gelfand, Rennert & Feldman, LLC
# 73              Genesis Merchant Services
# 93                    Interactive Brokers
# 99                                   KBRA
# 105    LSEG (London Stock Exchange Group)
# 107                           MarketAxess
# 145                  PitchBook Data, Inc.
# 158                          Santander US
# 170                     StoneX Group Inc.
# Name: Employer, dtype: object

# %%
banking['Employer']
# Out:
# 9                         American Express
# 17                           Bank of China
# 146                 PNC Financial Services
# 174    Sumitomo Mitsui Trust Bank, Limited
# Name: Employer, dtype: object

# %%
investment['Employer']
# Out:
# 25                         BNP Paribas
# 97                JPMorgan Chase & Co.
# 112                     Morgan Stanley
# 114                               MUFG
# 125    Nomura Securities International
# Name: Employer, dtype: object

# %%
mkt = data[data['Employer Industry'] == 'Advertising, PR & Marketing']
mkt
# Out:
#            Employer            Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                          Website                    Job Types                                                 School Years opt/cpt sponsor
# ...

# %%
tech =data[data['Employer Industry']=='Information Technology']
tech
# Out:
#                 Employer       Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                        Website Job Types                                                                                                                                                                                                                         School Years opt/cpt sponsor
# ...

# %%
#all_financial, banking, investment, mkt, tech
table = pd.concat([all_financial, banking, investment, mkt, tech], axis=0)
print(table.shape)
table
# Out:
# (31, 8)
#                                 Employer            Employer Industry                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description                                                                Website                         Job Types                                                                                                                                                                                                                         School Years opt/cpt sponsor
# ...

# %%
table.to_csv('nyu_rufen_table', index = True)
